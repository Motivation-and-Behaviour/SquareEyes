# %% [markdown]
# Test the accuracy of the default model without additional training data

# %% [markdown]
# Libraries

# %%
import glob as glob
import numpy as np
import cv2
import pandas as pd
import keras
import os
from keras.applications.inception_v3 import preprocess_input, decode_predictions
from sklearn.metrics import classification_report, confusion_matrix
from IPython.display import clear_output

# %%
# Import the pre-trained model
from keras.applications import InceptionV3

# %%
# Start the model
model = InceptionV3()
labels = pd.read_csv("categories.csv")

# %%
# make a function to make a prediction on a folder of images
def predict_and_save(folder, coded_data):
    predict_files = glob.glob(folder+'/*/*.jpg')
    
    predictor, prob, image_id = [], [], []
    final = pd.DataFrame(columns=['id','prediction','confidence','image'])
    
    not_coded = []
    
    for index, i in enumerate(predict_files):
        if coded_data["filename"].str.contains(os.path.basename(i)).any():
            clear_output(wait=True)
            print(f"Working on image {index} of {len(predict_files)-1}")
            im = cv2.imread(i)
            im = cv2.resize(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), (299, 299)).astype(np.float32) / 255.0
            im = np.expand_dims(im, axis =0)
            preds = model.predict(im)
            preds = decode_predictions(preds)[0]        

            temp_df = pd.DataFrame(preds,columns=['id','prediction','confidence'])
            temp_df['image'] = i.rsplit("/")[-1]
            final = final.append(temp_df)
            if index % 50 == 0:
                final.to_csv(folder+'_test.csv',index=False)
        else:
            not_coded.append(i)
        
    final.to_csv(folder+'_test.csv',index=False)
    return final

# %% [markdown]
# ## Test against Bridget's coding

# %%
coded_data = "/Volumes/M&B/Screen_Time_Measure_Development/SNAP_IT/Coding Framework Test Images/Screen Time Coding Data - Device.csv"
folder = "/Volumes/M&B/Screen_Time_Measure_Development/SNAP_IT/Coding Framework Test Images"

# %%
coded_data = pd.read_csv(coded_data)

# %%
# %%time
df = predict_and_save(folder, coded_data)
# Out:
# Working on image 4495 of 4495
# CPU times: user 3h 4min 34s, sys: 7min 56s, total: 3h 12min 30s
# Wall time: 1h 4min 39s

# %%
cat_maybe = ['computer_keyboard','projector', 'joystick',]

cat_def = ['desktop_computer', 'monitor', 'screen',
        'television', 'laptop',  
       'hand-held_computer', 'web_site',  'iPod',
       'home_theater', 'entertainment_center',
       'cellular_telephone']

# %%
df['screen_def'] = np.where(df["prediction"].isin(cat_def),1,0)
df['screen_maybe'] = np.where(df["prediction"].isin(cat_def + cat_maybe),1,0)

# %%
def conf_def(df, confthresh):
    if df["confidence"] > confthresh and df["screen_def"]==1:
        return 1
    else:
        return 0
def conf_maybe(df, confthresh):
    if df["confidence"] > confthresh and df["screen_maybe"]==1:
        return 1
    else:
        return 0

# %%
for x in np.arange(0.05, 0.501,0.05):
    df["screen_def_"+str(x)] = df.apply(conf_def, confthresh=x, axis=1)
    df["screen_maybe_"+str(x)] = df.apply(conf_maybe, confthresh=x, axis=1)

# %%
df = df.merge(coded_data,left_on="image", right_on="filename")
df.drop(columns="filename", inplace=True)
df[["device","device_excl_bkg"]] = df[["device","device_excl_bkg"]].astype(int)
df = df.drop(columns=["prediction","confidence","id"]).groupby(["image"]).any()

# %%
true_devices = ['device', 'device_excl_bkg']
predicted_devices = ['screen_def_0.05', 'screen_maybe_0.05',
       'screen_def_0.1', 'screen_maybe_0.1', 'screen_def_0.15000000000000002',
       'screen_maybe_0.15000000000000002', 'screen_def_0.2',
       'screen_maybe_0.2', 'screen_def_0.25', 'screen_maybe_0.25',
       'screen_def_0.3', 'screen_maybe_0.3', 'screen_def_0.35000000000000003',
       'screen_maybe_0.35000000000000003', 'screen_def_0.4',
       'screen_maybe_0.4', 'screen_def_0.45', 'screen_maybe_0.45',
       'screen_def_0.5', 'screen_maybe_0.5']

# %%
for true_device in true_devices:
    for predicted_device in predicted_devices:
        print(f"Comparing: {true_device} & {predicted_device}")
        print(classification_report(df[true_device], df[predicted_device]))
# Out:
# Comparing: device & screen_def_0.05
#               precision    recall  f1-score   support
#
#        False       0.50      0.81      0.62      1484
#         True       0.86      0.60      0.71      3011
#
#     accuracy                           0.67      4495
#    macro avg       0.68      0.71      0.66      4495
# weighted avg       0.74      0.67      0.68      4495
#
# Comparing: device & screen_maybe_0.05
#               precision    recall  f1-score   support
#
#        False       0.52      0.78      0.63      1484
#         True       0.86      0.65      0.74      3011
#
#     accuracy                           0.69      4495
#    macro avg       0.69      0.71      0.68      4495
# weighted avg       0.75      0.69      0.70      4495
#
# Comparing: device & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.48      0.90      0.62      1484
#         True       0.91      0.51      0.66      3011
#
#     accuracy                           0.64      4495
#    macro avg       0.69      0.71      0.64      4495
# weighted avg       0.77      0.64      0.65      4495
#
# Comparing: device & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.49      0.88      0.63      1484
#         True       0.91      0.55      0.69      3011
#
#     accuracy                           0.66      4495
#    macro avg       0.70      0.72      0.66      4495
# weighted avg       0.77      0.66      0.67      4495
#
# Comparing: device & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.45      0.93      0.61      1484
#         True       0.93      0.45      0.60      3011
#
#     accuracy                           0.61      4495
#    macro avg       0.69      0.69      0.61      4495
# weighted avg       0.77      0.61      0.61      4495
#
# Comparing: device & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.47      0.92      0.62      1484
#         True       0.93      0.48      0.63      3011
#
#     accuracy                           0.63      4495
#    macro avg       0.70      0.70      0.63      4495
# weighted avg       0.78      0.63      0.63      4495
#
# Comparing: device & screen_def_0.2
#               precision    recall  f1-score   support
#
#        False       0.44      0.96      0.60      1484
#         True       0.95      0.40      0.57      3011
#
#     accuracy                           0.59      4495
#    macro avg       0.70      0.68      0.58      4495
# weighted avg       0.78      0.59      0.58      4495
#
# Comparing: device & screen_maybe_0.2
#               precision    recall  f1-score   support
#
#        False       0.45      0.95      0.61      1484
#         True       0.95      0.43      0.59      3011
#
#     accuracy                           0.60      4495
#    macro avg       0.70      0.69      0.60      4495
# weighted avg       0.79      0.60      0.60      4495
#
# Comparing: device & screen_def_0.25
#               precision    recall  f1-score   support
#
#        False       0.43      0.97      0.59      1484
#         True       0.96      0.36      0.52      3011
#
#     accuracy                           0.56      4495
#    macro avg       0.69      0.66      0.56      4495
# weighted avg       0.78      0.56      0.55      4495
#
# Comparing: device & screen_maybe_0.25
#               precision    recall  f1-score   support
#
#        False       0.43      0.96      0.60      1484
#         True       0.96      0.38      0.54      3011
#
#     accuracy                           0.57      4495
#    macro avg       0.70      0.67      0.57      4495
# weighted avg       0.78      0.57      0.56      4495
#
# Comparing: device & screen_def_0.3
#               precision    recall  f1-score   support
#
#        False       0.41      0.98      0.58      1484
#         True       0.97      0.31      0.46      3011
#
#     accuracy                           0.53      4495
#    macro avg       0.69      0.64      0.52      4495
# weighted avg       0.78      0.53      0.50      4495
#
# Comparing: device & screen_maybe_0.3
#               precision    recall  f1-score   support
#
#        False       0.42      0.98      0.58      1484
#         True       0.96      0.32      0.48      3011
#
#     accuracy                           0.54      4495
#    macro avg       0.69      0.65      0.53      4495
# weighted avg       0.78      0.54      0.52      4495
#
# Comparing: device & screen_def_0.35000000000000003
#               precision    recall  f1-score   support
#
#        False       0.40      0.98      0.56      1484
#         True       0.97      0.26      0.41      3011
#
#     accuracy                           0.50      4495
#    macro avg       0.68      0.62      0.49      4495
# weighted avg       0.78      0.50      0.46      4495
#
# Comparing: device & screen_maybe_0.35000000000000003
#               precision    recall  f1-score   support
#
#        False       0.40      0.98      0.57      1484
#         True       0.97      0.27      0.43      3011
#
#     accuracy                           0.51      4495
#    macro avg       0.68      0.63      0.50      4495
# weighted avg       0.78      0.51      0.47      4495
#
# Comparing: device & screen_def_0.4
#               precision    recall  f1-score   support
#
#        False       0.38      0.99      0.55      1484
#         True       0.97      0.22      0.36      3011
#
#     accuracy                           0.47      4495
#    macro avg       0.68      0.60      0.46      4495
# weighted avg       0.78      0.47      0.42      4495
#
# Comparing: device & screen_maybe_0.4
#               precision    recall  f1-score   support
#
#        False       0.39      0.99      0.56      1484
#         True       0.97      0.23      0.37      3011
#
#     accuracy                           0.48      4495
#    macro avg       0.68      0.61      0.46      4495
# weighted avg       0.78      0.48      0.43      4495
#
# Comparing: device & screen_def_0.45
#               precision    recall  f1-score   support
#
#        False       0.37      0.99      0.54      1484
#         True       0.97      0.18      0.31      3011
#
#     accuracy                           0.45      4495
#    macro avg       0.67      0.59      0.43      4495
# weighted avg       0.77      0.45      0.39      4495
#
# Comparing: device & screen_maybe_0.45
#               precision    recall  f1-score   support
#
#        False       0.38      0.99      0.54      1484
#         True       0.97      0.19      0.32      3011
#
#     accuracy                           0.46      4495
#    macro avg       0.67      0.59      0.43      4495
# weighted avg       0.77      0.46      0.40      4495
#
# Comparing: device & screen_def_0.5
#               precision    recall  f1-score   support
#
#        False       0.37      0.99      0.53      1484
#         True       0.98      0.15      0.26      3011
#
#     accuracy                           0.43      4495
#    macro avg       0.67      0.57      0.40      4495
# weighted avg       0.78      0.43      0.35      4495
#
# Comparing: device & screen_maybe_0.5
#               precision    recall  f1-score   support
#
#        False       0.37      0.99      0.54      1484
#         True       0.98      0.16      0.27      3011
#
#     accuracy                           0.43      4495
#    macro avg       0.67      0.58      0.40      4495
# weighted avg       0.77      0.43      0.36      4495
#
# Comparing: device_excl_bkg & screen_def_0.05
#               precision    recall  f1-score   support
#
#        False       0.52      0.80      0.63      1573
#         True       0.85      0.61      0.71      2922
#
#     accuracy                           0.67      4495
#    macro avg       0.69      0.70      0.67      4495
# weighted avg       0.73      0.67      0.68      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.05
#               precision    recall  f1-score   support
#
#        False       0.55      0.77      0.64      1573
#         True       0.84      0.66      0.74      2922
#
#     accuracy                           0.69      4495
#    macro avg       0.69      0.71      0.69      4495
# weighted avg       0.74      0.69      0.70      4495
#
# Comparing: device_excl_bkg & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.50      0.89      0.64      1573
#         True       0.90      0.52      0.66      2922
#
#     accuracy                           0.65      4495
#    macro avg       0.70      0.70      0.65      4495
# weighted avg       0.76      0.65      0.65      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.52      0.87      0.65      1573
#         True       0.89      0.56      0.69      2922
#
#     accuracy                           0.67      4495
#    macro avg       0.70      0.72      0.67      4495
# weighted avg       0.76      0.67      0.67      4495
#
# Comparing: device_excl_bkg & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.48      0.93      0.63      1573
#         True       0.92      0.45      0.61      2922
#
#     accuracy                           0.62      4495
#    macro avg       0.70      0.69      0.62      4495
# weighted avg       0.76      0.62      0.62      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.49      0.92      0.64      1573
#         True       0.92      0.49      0.64      2922
#
#     accuracy                           0.64      4495
#    macro avg       0.70      0.70      0.64      4495
# weighted avg       0.77      0.64      0.64      4495
#
# Comparing: device_excl_bkg & screen_def_0.2
#               precision    recall  f1-score   support
#
#        False       0.46      0.95      0.62      1573
#         True       0.94      0.41      0.57      2922
#
#     accuracy                           0.60      4495
#    macro avg       0.70      0.68      0.60      4495
# weighted avg       0.77      0.60      0.59      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.2
#               precision    recall  f1-score   support
#
#        False       0.47      0.95      0.63      1573
#         True       0.94      0.44      0.59      2922
#
#     accuracy                           0.61      4495
#    macro avg       0.71      0.69      0.61      4495
# weighted avg       0.78      0.61      0.61      4495
#
# Comparing: device_excl_bkg & screen_def_0.25
#               precision    recall  f1-score   support
#
#        False       0.45      0.96      0.61      1573
#         True       0.95      0.36      0.53      2922
#
#     accuracy                           0.57      4495
#    macro avg       0.70      0.66      0.57      4495
# weighted avg       0.77      0.57      0.56      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.25
#               precision    recall  f1-score   support
#
#        False       0.46      0.96      0.62      1573
#         True       0.95      0.39      0.55      2922
#
#     accuracy                           0.59      4495
#    macro avg       0.70      0.67      0.58      4495
# weighted avg       0.77      0.59      0.57      4495
#
# Comparing: device_excl_bkg & screen_def_0.3
#               precision    recall  f1-score   support
#
#        False       0.43      0.98      0.60      1573
#         True       0.96      0.31      0.47      2922
#
#     accuracy                           0.54      4495
#    macro avg       0.70      0.64      0.54      4495
# weighted avg       0.77      0.54      0.52      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.3
#               precision    recall  f1-score   support
#
#        False       0.44      0.97      0.60      1573
#         True       0.96      0.33      0.49      2922
#
#     accuracy                           0.56      4495
#    macro avg       0.70      0.65      0.55      4495
# weighted avg       0.78      0.56      0.53      4495
#
# Comparing: device_excl_bkg & screen_def_0.35000000000000003
#               precision    recall  f1-score   support
#
#        False       0.42      0.98      0.59      1573
#         True       0.96      0.27      0.42      2922
#
#     accuracy                           0.52      4495
#    macro avg       0.69      0.62      0.50      4495
# weighted avg       0.77      0.52      0.48      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.35000000000000003
#               precision    recall  f1-score   support
#
#        False       0.42      0.98      0.59      1573
#         True       0.96      0.28      0.43      2922
#
#     accuracy                           0.52      4495
#    macro avg       0.69      0.63      0.51      4495
# weighted avg       0.77      0.52      0.49      4495
#
# Comparing: device_excl_bkg & screen_def_0.4
#               precision    recall  f1-score   support
#
#        False       0.41      0.98      0.57      1573
#         True       0.96      0.22      0.36      2922
#
#     accuracy                           0.49      4495
#    macro avg       0.68      0.60      0.47      4495
# weighted avg       0.77      0.49      0.44      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.4
#               precision    recall  f1-score   support
#
#        False       0.41      0.98      0.58      1573
#         True       0.96      0.24      0.38      2922
#
#     accuracy                           0.50      4495
#    macro avg       0.69      0.61      0.48      4495
# weighted avg       0.77      0.50      0.45      4495
#
# Comparing: device_excl_bkg & screen_def_0.45
#               precision    recall  f1-score   support
#
#        False       0.40      0.99      0.56      1573
#         True       0.96      0.19      0.31      2922
#
#     accuracy                           0.47      4495
#    macro avg       0.68      0.59      0.44      4495
# weighted avg       0.76      0.47      0.40      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.45
#               precision    recall  f1-score   support
#
#        False       0.40      0.98      0.57      1573
#         True       0.96      0.20      0.33      2922
#
#     accuracy                           0.47      4495
#    macro avg       0.68      0.59      0.45      4495
# weighted avg       0.76      0.47      0.41      4495
#
# Comparing: device_excl_bkg & screen_def_0.5
#               precision    recall  f1-score   support
#
#        False       0.39      0.99      0.56      1573
#         True       0.97      0.16      0.27      2922
#
#     accuracy                           0.45      4495
#    macro avg       0.68      0.57      0.41      4495
# weighted avg       0.77      0.45      0.37      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.5
#               precision    recall  f1-score   support
#
#        False       0.39      0.99      0.56      1573
#         True       0.97      0.16      0.28      2922
#
#     accuracy                           0.45      4495
#    macro avg       0.68      0.58      0.42      4495
# weighted avg       0.76      0.45      0.38      4495
