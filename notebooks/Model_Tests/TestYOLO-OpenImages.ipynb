# %%
import glob as glob
import os

import cv2
import numpy as np
import pandas as pd
from IPython.display import clear_output
from sklearn.metrics import (
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    roc_auc_score,
)

# %%
# Load the labels
LABELS = open("/Users/tasanders/Google Drive/Square Eyes (DP20)/5 - Data collection and management/Image Blurring Test/Yolo/openimages.names").read().strip().split("\n")

# %%
# Get the weights and config
configpath = "/Users/tasanders/Google Drive/Square Eyes (DP20)/5 - Data collection and management/Image Blurring Test/Yolo/yolov3-openimages.cfg"
weightspath = "/Users/tasanders/Google Drive/Square Eyes (DP20)/5 - Data collection and management/Image Blurring Test/Yolo/yolov3-openimages.weights"

net = cv2.dnn.readNetFromDarknet(configpath, weightspath)

# Determine the output layer names
ln = net.getLayerNames()
ln = [ln[i[0]-1] for i in net.getUnconnectedOutLayers()]

# %%
# Function to make a prediction and save to df
def predict_and_save(folder, coded_data, conf_thresh=0.1, nms_thresh=0.15):
    predict_files = glob.glob(folder + "/*/*.jpg")

    predictor, prob, image_id = [], [], []
    final = pd.DataFrame(columns=["id", "prediction", "confidence", "image"])

    not_coded = []

    for index, image in enumerate(predict_files):
        if coded_data["filename"].str.contains(os.path.basename(image)).any():
            clear_output(wait=True)
            print(f"Working on image {index} of {len(predict_files)-1}")

            im = cv2.imread(image)
            (H, W) = im.shape[:2]

            # Create the blob
            blob = cv2.dnn.blobFromImage(
                im, 1 / 255.0, (416, 416), swapRB=True, crop=False
            )
            net.setInput(blob)
            layerOutputs = net.forward(ln)

            # Translate the predictions
            boxes = []
            confidences = []
            classIDs = []

            for output in layerOutputs:
                for detection in output:
                    scores = detection[5:]
                    classID = np.argmax(scores)
                    confidence = scores[classID]

                    if confidence > conf_thresh:
                        box = detection[0:4] * np.array([W, H, W, H])
                        (centerX, centerY, width, height) = box.astype("int")
                        x = int(centerX - (width / 2))
                        y = int(centerY - (height / 2))
                        # update our list of bounding box coordinates, confidences, and class IDs
                        boxes.append([x, y, int(width), int(height)])
                        confidences.append(float(confidence))
                        classIDs.append(classID)

            # apply non-maxima suppression to suppress weak, overlapping bounding boxes
            idxs = cv2.dnn.NMSBoxes(boxes, confidences, conf_thresh, nms_thresh)

            # Append to df
            if len(idxs):
                for i in idxs.flatten():
                    final = final.append(
                        {
                            "id": classIDs[i],
                            "prediction": LABELS[classIDs[i]],
                            "confidence": confidences[i],
                            "image": os.path.basename(image),
                        },
                        ignore_index=True,
                    )
            else:  # no predictions made
                final = final.append(
                    {
                        "id": None,
                        "prediction": None,
                        "confidence": None,
                        "image": os.path.basename(image),
                    },
                    ignore_index=True,
                )

    return final

# %% [markdown]
# ##  Test against Bridget's coding

# %%
# %%time
coded_data = pd.read_csv("/Volumes/M&B/Screen_Time_Measure_Development/SNAP_IT/Coding Framework Test Images/Screen Time Coding Data - Device.csv")
folder = "/Volumes/M&B/Screen_Time_Measure_Development/SNAP_IT/Coding Framework Test Images"
df = predict_and_save(folder, coded_data)
# Out:
# Working on image 4495 of 4495
# CPU times: user 3h 26min 48s, sys: 2min 11s, total: 3h 28min 59s
# Wall time: 1h 4min 28s

# %%
df_backup = df.copy()
df.to_csv(
    "/Volumes/M&B/Screen_Time_Measure_Development/SNAP_IT/Coding Framework Test Images/YOLO-OpenImages.csv",
    index=False,
)

# %%
cat_maybe = [
    "Computer keyboard",
    "Printer",
    "Computer mouse",
    "Remote control",
]

cat_def = [
    "Laptop",
    "Computer monitor",
    "Mobile phone",
    "Television",
    "Tablet computer",
    "Ipod",
]

# %%
df['screen_def'] = np.where(df["prediction"].isin(cat_def),1,0)
df['screen_maybe'] = np.where(df["prediction"].isin(cat_def + cat_maybe),1,0)

# %%
def conf_def(df, confthresh):
    if df["confidence"] > confthresh and df["screen_def"]==1:
        return 1
    else:
        return 0
def conf_maybe(df, confthresh):
    if df["confidence"] > confthresh and df["screen_maybe"]==1:
        return 1
    else:
        return 0

# %%
for x in np.arange(0.1, 0.501,0.05):
    df["screen_def_"+str(x)] = df.apply(conf_def, confthresh=x, axis=1)
    df["screen_maybe_"+str(x)] = df.apply(conf_maybe, confthresh=x, axis=1)

# %%
df = df.merge(coded_data,left_on="image", right_on="filename")
df.drop(columns="filename", inplace=True)
df[["device","device_excl_bkg"]] = df[["device","device_excl_bkg"]].astype(int)
df = df.drop(columns=["prediction","confidence","id"]).groupby(["image"]).any()

# %%
true_devices = ['device', 'device_excl_bkg']
predicted_devices = df.drop(columns=['device', 'device_excl_bkg','screen_def', 'screen_maybe',])

# %%
for true_device in true_devices:
    for predicted_device in predicted_devices:
        print(f"Comparing: {true_device} & {predicted_device}")
        print(classification_report(df[true_device], df[predicted_device]))
# Out:
# Comparing: device & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.50      1484
#         True       1.00      0.03      0.05      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.51      0.28      4495
# weighted avg       0.78      0.35      0.20      4495
#
# Comparing: device & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.51      1484
#         True       1.00      0.03      0.07      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.52      0.29      4495
# weighted avg       0.78      0.35      0.21      4495
#
# Comparing: device & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.50      1484
#         True       1.00      0.03      0.05      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.51      0.28      4495
# weighted avg       0.78      0.35      0.20      4495
#
# Comparing: device & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.51      1484
#         True       1.00      0.03      0.07      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.52      0.29      4495
# weighted avg       0.78      0.35      0.21      4495
#
# Comparing: device & screen_def_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.50      1484
#         True       1.00      0.03      0.05      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.51      0.28      4495
# weighted avg       0.78      0.35      0.20      4495
#
# Comparing: device & screen_maybe_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.34      1.00      0.51      1484
#         True       1.00      0.03      0.07      3011
#
#     accuracy                           0.35      4495
#    macro avg       0.67      0.52      0.29      4495
# weighted avg       0.78      0.35      0.21      4495
#
# Comparing: device & screen_def_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.01      0.03      3011
#
#     accuracy                           0.34      4495
#    macro avg       0.67      0.51      0.26      4495
# weighted avg       0.78      0.34      0.18      4495
#
# Comparing: device & screen_maybe_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.02      0.04      3011
#
#     accuracy                           0.34      4495
#    macro avg       0.67      0.51      0.27      4495
# weighted avg       0.78      0.34      0.19      4495
#
# Comparing: device & screen_def_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.01      0.02      3011
#
#     accuracy                           0.34      4495
#    macro avg       0.67      0.51      0.26      4495
# weighted avg       0.78      0.34      0.18      4495
#
# Comparing: device & screen_maybe_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.01      0.02      3011
#
#     accuracy                           0.34      4495
#    macro avg       0.67      0.51      0.26      4495
# weighted avg       0.78      0.34      0.18      4495
#
# Comparing: device & screen_def_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.01      0.01      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.26      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_maybe_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.01      0.01      3011
#
#     accuracy                           0.34      4495
#    macro avg       0.67      0.50      0.26      4495
# weighted avg       0.78      0.34      0.17      4495
#
# Comparing: device & screen_def_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.01      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_maybe_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.01      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_def_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.01      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_maybe_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.01      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_def_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device & screen_maybe_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       1.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.67      0.50      0.25      4495
# weighted avg       0.78      0.33      0.17      4495
#
# Comparing: device_excl_bkg & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.05      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.51      0.29      4495
# weighted avg       0.77      0.37      0.22      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.07      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.52      0.30      4495
# weighted avg       0.77      0.37      0.23      4495
#
# Comparing: device_excl_bkg & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.05      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.51      0.29      4495
# weighted avg       0.77      0.37      0.22      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.07      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.52      0.30      4495
# weighted avg       0.77      0.37      0.23      4495
#
# Comparing: device_excl_bkg & screen_def_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.05      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.51      0.29      4495
# weighted avg       0.77      0.37      0.22      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.36      1.00      0.53      1573
#         True       0.99      0.03      0.07      2922
#
#     accuracy                           0.37      4495
#    macro avg       0.67      0.52      0.30      4495
# weighted avg       0.77      0.37      0.23      4495
#
# Comparing: device_excl_bkg & screen_def_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.98      0.02      0.03      2922
#
#     accuracy                           0.36      4495
#    macro avg       0.67      0.51      0.28      4495
# weighted avg       0.76      0.36      0.20      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.98      0.02      0.04      2922
#
#     accuracy                           0.36      4495
#    macro avg       0.67      0.51      0.28      4495
# weighted avg       0.76      0.36      0.21      4495
#
# Comparing: device_excl_bkg & screen_def_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.01      0.02      2922
#
#     accuracy                           0.36      4495
#    macro avg       0.68      0.51      0.27      4495
# weighted avg       0.77      0.36      0.20      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.01      0.03      2922
#
#     accuracy                           0.36      4495
#    macro avg       0.68      0.51      0.27      4495
# weighted avg       0.77      0.36      0.20      4495
#
# Comparing: device_excl_bkg & screen_def_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.01      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.27      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.01      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.27      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_def_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_def_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.01      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.19      4495
#
# Comparing: device_excl_bkg & screen_def_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       1.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.68      0.50      0.26      4495
# weighted avg       0.77      0.35      0.18      4495

# %% [markdown]
# Possible that the labels are incorrect? Test a different ordering of the labels.

# %%
LABELS_ALT = open("/Users/tasanders/Google Drive/Square Eyes (DP20)/5 - Data collection and management/Image Blurring Test/Yolo/yolo.names").read().strip().split("\n")

# %%
df_alt=df_backup.copy()

# %%
df_alt = df_alt.merge(pd.DataFrame(LABELS_ALT),how='left',left_on="id", right_index=True)
df_alt.drop(columns="prediction",inplace=True)
df_alt.rename(columns={0:"prediction"}, inplace=True)

# %%
df_alt['screen_def'] = np.where(df_alt["prediction"].isin(cat_def),1,0)
df_alt['screen_maybe'] = np.where(df_alt["prediction"].isin(cat_def + cat_maybe),1,0)

# %%
for x in np.arange(0.1, 0.501,0.05):
    df_alt["screen_def_"+str(x)] = df_alt.apply(conf_def, confthresh=x, axis=1)
    df_alt["screen_maybe_"+str(x)] = df_alt.apply(conf_maybe, confthresh=x, axis=1)

# %%
df_alt = df_alt.merge(coded_data,left_on="image", right_on="filename")
df_alt.drop(columns="filename", inplace=True)
df_alt[["device","device_excl_bkg"]] = df_alt[["device","device_excl_bkg"]].astype(int)
df_alt = df_alt.drop(columns=["prediction","confidence","id"]).groupby(["image"]).any()

# %%
for true_device in true_devices:
    for predicted_device in predicted_devices:
        print(f"Comparing: {true_device} & {predicted_device}")
        print(classification_report(df_alt[true_device], df_alt[predicted_device]))
# Out:
# Comparing: device & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_def_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device & screen_maybe_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.33      1.00      0.50      1484
#         True       0.00      0.00      0.00      3011
#
#     accuracy                           0.33      4495
#    macro avg       0.17      0.50      0.25      4495
# weighted avg       0.11      0.33      0.16      4495
#
# Comparing: device_excl_bkg & screen_def_0.1
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.1
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.15000000000000002
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.20000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.25000000000000006
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.30000000000000004
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.3500000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.40000000000000013
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.45000000000000007
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.45000000000000007
# /Users/tasanders/opt/anaconda3/envs/square_eyes/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_def_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
#
# Comparing: device_excl_bkg & screen_maybe_0.5000000000000001
#               precision    recall  f1-score   support
#
#        False       0.35      1.00      0.52      1573
#         True       0.00      0.00      0.00      2922
#
#     accuracy                           0.35      4495
#    macro avg       0.17      0.50      0.26      4495
# weighted avg       0.12      0.35      0.18      4495
