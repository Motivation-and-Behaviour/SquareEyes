# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
model = YOLO('yolov8x.pt')  # pretrained YOLOv8n model
# Out:
# ...
# 100%|██████████| 131M/131M [00:06<00:00, 20.1MB/s]

# %%
test_images = ["/home/tasanders/Documents/SquareEyes_TestImages/1637vid1image00001.jpg", "/home/tasanders/Documents/SquareEyes_TestImages/1637vid2image00001.jpg", "/home/tasanders/Documents/SquareEyes_TestImages/1637vid2image00002.jpg"]
results = model(test_images)
# Out:
# 0: 384x640 2 chairs, 1 tv, 1 keyboard, 1 cell phone, 1 book, 1: 384x640 1 person, 1 cup, 1 potted plant, 1 tv, 1 mouse, 1 keyboard, 2: 384x640 2 potted plants, 2 tvs, 1 mouse, 1 keyboard, 1 book, 104.8ms
# Speed: 1.7ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
res_plot = results[0].plot()
plt.imshow(res_plot)
plt.show()

# %%
model.info(0)
# Out:
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
# (268, 68200608, 0, 0.0)
